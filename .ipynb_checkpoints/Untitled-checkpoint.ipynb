# %%
# %%writefile Procfile
# web: gunicorn bike:app
# Out:
# Writing Procfile

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'
